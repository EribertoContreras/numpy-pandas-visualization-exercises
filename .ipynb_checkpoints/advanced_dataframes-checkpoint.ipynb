# %% [markdown]
# # Exercise 1

# %%
import numpy as np
import pandas as pd
from env import get_db_url

#get_db_url

# %%
url = get_db_url('employees') #this is important.... do not print

# %%
#4
sql = """
SELECT * FROM employees
"""
emp = pd.read_sql(sql, url)
emp.shape
# Out:
# (300024, 6)

# %%
sql = """
SELECT * FROM titles
"""

titles = pd.read_sql(sql, url)
titles.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
# How many rows and columns do you have in each DataFrame?
#Is that what you expected?
titles.describe(include="all")
# Out:
#                emp_no     title   from_date     to_date
# count   443308.000000    443308      443308      443308
# unique            NaN         7        6393        5888
# top               NaN  Engineer  1998-10-25  9999-01-01
# freq              NaN    115003         132      240124
# mean    253075.034430       NaN         NaN         NaN
# std     161853.292613       NaN         NaN         NaN
# min      10001.000000       NaN         NaN         NaN
# 25%      84855.750000       NaN         NaN         NaN
# 50%     249847.500000       NaN         NaN         NaN
# 75%     424891.250000       NaN         NaN         NaN
# max     499999.000000       NaN         NaN         NaN

# %%
#9 How many unique titles are in the titles DataFrame?

pd.read_sql("SELECT COUNT(DISTINCT title) AS unique_title_count from titles", url)
# Out:
#    unique_title_count
# 0                   7

# %%
#10 What is the oldest date in the to_date column?
len(titles.title.unique())
# Out:
# 7

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
#11 What is the most recent date in the to_date column?
pd.read_sql("SELECT MAX(to_date) FROM titles", url)
# Out:
#   MAX(to_date)
# 0   9999-01-01

# %% [markdown]
# # Excercise 2

# %% [markdown]
#  df.loc[:, 'math':'reading']
#
# df.loc[: is the first number column... needed, 'math','reading']
#
# link : https://ds.codeup.com/python/advanced-dataframes/#exercises-i

# %%
# loc alters the original

# %%
#df.iloc[start:end]   : cuts things with iloc

# %%
# .agg is the same as grouping in sql

# %%
#df.assign is another way to generating another column

# %%
#.T = transforms everything to the side

# %%
#pd.concat brings things together. pd.concat([df.column, df.column])

# %% [markdown]
# 1) Copy the users and roles DataFrames from the examples above.

# %%
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# 2) What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, left_on='role_id',
            right_on='id', how='right', indicator=True)
#"how" join type
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %% [markdown]
# 2) What is the result of using a right join on the DataFrames?
# returns results that have valid info on the right

# %%
users.merge(roles, left_on='role_id',
            right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %% [markdown]
# 3) What is the result of using an outer join on the DataFrames?
# outer keeps stuff thats valif on the left and right

# %% [markdown]
# 4) What happens if you drop the foreign keys from the DataFrames and try to merge them?     You would not be able to merge.... it would give you an error code.

# %% [markdown]
# 5) Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')

# %% [markdown]
# 6) Output and read the documentation for the mpg dataset.

# %%
mpg= data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %% [markdown]
# 7)How many rows and columns are in the dataset? 234 rows x 11 columns

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8) Check out your column names and perform any cleanup you may want on them.

# %%
#mpg.rename(columns = {'cty' : 'city', 'hwy' : 'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
mpg.columns.tolist()
# Out:
# ['manufacturer',
#  'model',
#  'displ',
#  'year',
#  'cyl',
#  'trans',
#  'drv',
#  'cty',
#  'hwy',
#  'fl',
#  'class']

# %%
mpg.columns = ['manufacturer',
 'model',
 'displ',
 'year',
 'cyl',
 'transmission',
 'drv',
 'city',
 'highway',
 'fl',
 'class']

# %% [markdown]
# 9)Display the summary statistics for the dataset.

# %% [markdown]
# 10)How many different manufacturers are there?

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# 11)How many different models are there?

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# 12) Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl transmission drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4     auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6     auto(l5)   f    16       26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %% [markdown]
# 13)Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway)/2

mpg.head()
# Out:
#   manufacturer model  displ  year  cyl transmission drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4     auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6     auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %% [markdown]
# 14)Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg.transmission.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
mpg['is_automatic'] = mpg.transmission.str.contains('auto')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl transmission drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4     auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6     auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage  is_automatic
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True

# %% [markdown]
# 15)Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
mpg.groupby('manufacturer').average_mileage.mean().sort_values(ascending = False)
# Out:
# manufacturer
# honda         28.500000
# volkswagen    25.074074
# hyundai       22.750000
# subaru        22.428571
# audi          22.027778
# toyota        21.720588
# pontiac       21.700000
# nissan        21.346154
# chevrolet     18.447368
# ford          16.680000
# mercury       15.625000
# jeep          15.562500
# dodge         15.540541
# lincoln       14.166667
# land rover    14.000000
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16)Do automatic or manual cars have better miles per gallon?

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl transmission drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4     auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6     auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage  is_automatic
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True

# %%
#np.where(condition,'this','that')
mpg['transmission_category'] = np.where(mpg.transmission.str.contains('auto'), 'automatic', 'manual')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl transmission drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4     auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6     auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage  is_automatic  \
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True
#
#   transmission_category
# 1             automatic
# 2                manual
# 3                manual
# 4             automatic
# ...

# %%
mpg.groupby('transmission_category')[['average_mileage']].mean().round(1)
# Out:
#                        average_mileage
# transmission_category
# automatic                         19.1
# manual                            22.2

# %% [markdown]
# # Exercises 3

# %% [markdown]
# NaN = Not a Number.... cannot compute

# %% [markdown]
# aggfunc= applied function like (median,sum,avg.ect...)

# %% [markdown]
# df.T turns the info on its side

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl transmission drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4     auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4   manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4   manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4     auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6     auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...          ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4     auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4   manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6     auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6   manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6     auto(s6)   f    17       26  p
#
# ...

# %%
mpg.T
# Out:
#                              1           2           3          4    \
# manufacturer                audi        audi        audi       audi
# model                         a4          a4          a4         a4
# displ                        1.8         1.8         2.0        2.0
# year                        1999        1999        2008       2008
# cyl                            4           4           4          4
# transmission            auto(l5)  manual(m5)  manual(m6)   auto(av)
# drv                            f           f           f          f
# city                          18          21          20         21
# highway                       29          29          31         30
# fl                             p           p           p          p
# class                    compact     compact     compact    compact
# mileage_difference            11           8          11          9
# average_mileage             23.5        25.0        25.5       25.5
# ...

# %% [markdown]
# 1)Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')

# %%
chipotle = pd.read_sql("SELECT * FROM orders", url)
chipotle
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
chipotle.columns = ['id', 'order_id', 'quantity', 'item_name', 'choice_description',
       'total_item_price']

# %%
chipotle.columns.tolist()
# Out:
# ['id',
#  'order_id',
#  'quantity',
#  'item_name',
#  'choice_description',
#  'total_item_price']

# %% [markdown]
# 2) What is the total price for each order?

# %%
# getting rid of symbols and turning it into a float number

chipotle['total_item_price'] = (chipotle.total_item_price.str.replace('$', '')).astype(float)

#pd.to_numeric(chipotle.total_item_price)
# Out:
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_17952/780765784.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipotle['total_item_price'] = (chipotle.total_item_price.str.replace('$', '')).astype(float)

# %%
pd.DataFrame(chipotle.groupby(['order_id']).total_item_price.sum())
# Out:
#           total_item_price
# order_id
# 1                    11.56
# 2                    16.98
# 3                    12.67
# 4                    21.00
# 5                    13.70
# ...                    ...
# 1830                 23.00
# 1831                 12.90
# 1832                 13.20
# 1833                 23.50
# 1834                 28.75
#
# [1834 rows x 1 columns]

# %% [markdown]
# 3)What are the most popular 3 items?

# %%
#pd.DataFrame will make it look nice
pd.DataFrame(chipotle.groupby('item_name').quantity.sum().sort_values(ascending = False).head(3))
# Out:
#                      quantity
# item_name
# Chicken Bowl              761
# Chicken Burrito           591
# Chips and Guacamole       506

# %% [markdown]
# 4)Which item has produced the most revenue?

# %%
pd.DataFrame(chipotle.groupby('item_name').total_item_price.sum().sort_values(ascending = False).head(3))
# Out:
#                  total_item_price
# item_name
# Chicken Bowl              7342.73
# Chicken Burrito           5575.82
# Steak Burrito             3851.43

# %% [markdown]
# 5)Join the employees and titles DataFrames together.

# %%
employees = emp

# %%
emp_titles = emp.merge(titles, left_on='emp_no', right_on='emp_no', how='inner', indicator=True)

emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date _merge
# 0       Senior Engineer  1986-06-26  9999-01-01   both
# ...

# %% [markdown]
# 6)For each title, find the hire date of the employee that was hired most recently with that title.

# %%
pd.DataFrame(emp_titles.groupby('title').hire_date.max().sort_values(ascending = False))
# Out:
#                      hire_date
# title
# Engineer            2000-01-28
# Senior Staff        2000-01-13
# Staff               2000-01-12
# Senior Engineer     2000-01-01
# Technique Leader    1999-12-31
# Assistant Engineer  1999-12-24
# Manager             1992-02-05

# %% [markdown]
# 7)Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
url = get_db_url('employees')

# %%
sql = """
SELECT * FROM departments
"""
department = pd.read_sql(sql, url)
department.shape
# Out:
# (9, 2)

# %%
sql = """
SELECT * FROM dept_emp
"""
dept_emp = pd.read_sql(sql, url)
dept_emp.shape
# Out:
# (331603, 4)

# %%
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
department
# Out:
#   dept_no           dept_name
# 0    d009    Customer Service
# 1    d005         Development
# 2    d002             Finance
# 3    d003     Human Resources
# 4    d001           Marketing
# 5    d004          Production
# 6    d006  Quality Management
# 7    d008            Research
# 8    d007               Sales

# %%
dept_emp
# Out:
#         emp_no dept_no   from_date     to_date
# 0        10001    d005  1986-06-26  9999-01-01
# 1        10002    d007  1996-08-03  9999-01-01
# 2        10003    d004  1995-12-03  9999-01-01
# 3        10004    d004  1986-12-01  9999-01-01
# 4        10005    d003  1989-09-12  9999-01-01
# ...        ...     ...         ...         ...
# 331598  499995    d004  1997-06-02  9999-01-01
# 331599  499996    d004  1996-05-13  9999-01-01
# 331600  499997    d005  1987-08-30  9999-01-01
# 331601  499998    d002  1993-12-27  9999-01-01
# 331602  499999    d004  1997-11-30  9999-01-01
#
# [331603 rows x 4 columns]

# %%
dd = dept_emp.merge(department, left_on='dept_no', right_on='dept_no', how='inner', indicator=True)

dd
# Out:
#         emp_no dept_no   from_date     to_date    dept_name _merge
# 0        10001    d005  1986-06-26  9999-01-01  Development   both
# 1        10006    d005  1990-08-05  9999-01-01  Development   both
# 2        10008    d005  1998-03-11  2000-07-31  Development   both
# 3        10012    d005  1992-12-18  9999-01-01  Development   both
# 4        10014    d005  1993-12-29  9999-01-01  Development   both
# ...        ...     ...         ...         ...          ...    ...
# 331598  499950    d002  1999-02-02  2000-02-23      Finance   both
# 331599  499975    d002  1996-10-19  1997-07-23      Finance   both
# 331600  499977    d002  1999-12-28  9999-01-01      Finance   both
# 331601  499989    d002  1996-10-29  2001-03-07      Finance   both
# 331602  499998    d002  1993-12-27  9999-01-01      Finance   both
#
# [331603 rows x 6 columns]

# %%
dd.columns
# Out:
# Index(['emp_no', 'dept_no', 'from_date', 'to_date', 'dept_name', '_merge'], dtype='object')

# %%
emp_titles.columns
# Out:
# Index(['emp_no', 'birth_date', 'first_name', 'last_name', 'gender',
#        'hire_date', 'title', 'from_date', 'to_date', '_merge'],
#       dtype='object')

# %%
dd_emp_titles = dd.merge(emp_titles, left_on='emp_no', right_on='emp_no', how='inner')
dd_emp_titles
# Out:
#         emp_no dept_no from_date_x   to_date_x    dept_name _merge_x  \
# 0        10001    d005  1986-06-26  9999-01-01  Development     both
# 1        10006    d005  1990-08-05  9999-01-01  Development     both
# 2        10008    d005  1998-03-11  2000-07-31  Development     both
# 3        10012    d005  1992-12-18  9999-01-01  Development     both
# 4        10012    d005  1992-12-18  9999-01-01  Development     both
# ...        ...     ...         ...         ...          ...      ...
# 489898  499950    d002  1999-02-02  2000-02-23      Finance     both
# 489899  499977    d002  1999-12-28  9999-01-01      Finance     both
# 489900  499989    d002  1996-10-29  2001-03-07      Finance     both
# 489901  499998    d002  1993-12-27  9999-01-01      Finance     both
# 489902  499998    d002  1993-12-27  9999-01-01      Finance     both
#
#         birth_date first_name  last_name gender   hire_date  \
# 0       1953-09-02     Georgi    Facello      M  1986-06-26
# ...

# %%
emp_titles_depts = pd.read_sql("""
SELECT
    *
    FROM employees
    JOIN titles USING (emp_no)
    JOIN dept_emp USING (emp_no)
    JOIN departments USING (dept_no)
""", url)
emp_titles_depts.head()
# Out:
#   dept_no  emp_no  birth_date first_name last_name gender   hire_date  \
# 0    d009   10011  1953-11-07       Mary     Sluis      F  1990-01-22
# 1    d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 2    d009   10038  1960-07-20       Huan     Lortz      M  1989-09-20
# 3    d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
# 4    d009   10049  1961-04-24      Basil    Tramer      F  1992-05-04
#
#           title   from_date     to_date   from_date     to_date  \
# 0         Staff  1990-01-22  1996-11-09  1990-01-22  1996-11-09
# 1  Senior Staff  1996-09-20  9999-01-01  1989-09-20  9999-01-01
# 2         Staff  1989-09-20  1996-09-20  1989-09-20  9999-01-01
# 3  Senior Staff  2000-05-04  9999-01-01  1992-05-04  9999-01-01
# 4         Staff  1992-05-04  2000-05-04  1992-05-04  9999-01-01
#
#           dept_name
# 0  Customer Service
# 1  Customer Service
# 2  Customer Service
# 3  Customer Service
# 4  Customer Service

# %% [markdown]
# Write the code necessary to create a cross tabulation of the number of titles by department.

# %%
pd.crosstab(dd_emp_titles.title, dd_emp_titles.dept_name, margins = True)  #this is not for current employees
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
# All                            35075       125586    26070            26618
#
# dept_name           Marketing  Production  Quality Management  Research  \
# title
# Assistant Engineer          0        6445                1831       378
# Engineer                    0       49649               13852      2986
# ...
